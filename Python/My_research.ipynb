# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from wordcloud import WordCloud
from PyPDF2 import PdfReader
import glob
from PIL import Image, ImageDraw
import matplotlib as mpl
# Out:
# /Users/JakeCanfield/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
trauma_path = '/Users/JakeCanfield/Documents/Trauma_Surgery_Research/'
topics = os.listdir(trauma_path + 'Papers/')
topics = [i for i in topics if not i.startswith('.')]

# %%
df = pd.DataFrame(columns=['Topic', '# of Papers Read'])
for i in topics:
    print(i)
    papers = os.listdir(trauma_path+'Papers/'+'%s'%i)
    papers = [i for i in papers if i != '.ipynb_checkpoints']
    df = df.append({'Topic':i,'# of Papers Read':len(papers)}, ignore_index=True)
df['# of Papers Read'] = df['# of Papers Read'].astype('int')
df = df.sort_values(by=['# of Papers Read'], ascending=False)
# Out:
# Sclerosing Agents
# Traumatic Hemothorax & Pneumothorax
# Databases
# Burn Injuries
# Cervical spine immobilization
# Extremity Vascular Injuries
# Blunt Cerebrovascular Injury
# Penetrating Thoracoabdominal Injury
# Coagulopathy of Trauma
# Imaging Studies
# Fluid Resuscitation
# Machine Learning with NTDB
# Penetrating Cervical Injury
# Long Bone Fractures & Extremity Compartment Syndrome
# Damage Control Surgery

# %%
f = sns.barplot(y=df['Topic'], x=df['# of Papers Read'],palette='viridis')
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set(rc={"figure.dpi":1000, 'savefig.dpi':300})
plt.savefig(trauma_path+'Python/papers_read_metrics', bbox_inches='tight')
mpl.rcParams['figure.dpi'] = 1000
sns.set_context("poster")
plt.show()
