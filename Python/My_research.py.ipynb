# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from wordcloud import WordCloud
from PyPDF2 import PdfReader
import glob
from PIL import Image, ImageDraw

# %%
trauma_path = '/Users/JakeCanfield/Documents/Trauma_Surgery_Research/'
topics = os.listdir(trauma_path + 'Papers/')
topics = [i for i in topics if i != '.DS_Store']

# %%
df = pd.DataFrame(columns=['Topic', '# of Papers Read'])
for i in topics:
    papers = os.listdir(trauma_path+'Papers/'+'%s'%i)
    papers = [i for i in papers if i != '.ipynb_checkpoints']
    df = df.append({'Topic':i,'# of Papers Read':len(papers)}, ignore_index=True)
df['# of Papers Read'] = df['# of Papers Read'].astype('int').sort_values('# of Papers Read')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-da0d6b9df770> in <module>
#       4     papers = [i for i in papers if i != '.ipynb_checkpoints']
#       5     df = df.append({'Topic':i,'# of Papers Read':len(papers)}, ignore_index=True)
# ----> 6 df['# of Papers Read'] = df['# of Papers Read'].astype('int').sort_values('# of Papers Read')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    2774         inplace = validate_bool_kwarg(inplace, 'inplace')
#    2775         # Validate the axis parameter
# -> 2776         self._get_axis_number(axis)
#    2777
#    2778         # GH 5856/5853
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     359                 pass
#     360         raise ValueError('No axis named {0} for object type {1}'
# --> 361                          .format(axis, type(cls)))
#     362
#     363     @classmethod
#
# ValueError: No axis named # of Papers Read for object type <class 'type'>

# %%
f = sns.barplot(y=df['Topic'], x=df['# of Papers Read'],palette='viridis')
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set(rc={"figure.dpi":10000, 'savefig.dpi':300})
plt.savefig(trauma_path+'Python/papers_read_metrics', bbox_inches='tight')
plt.show()
